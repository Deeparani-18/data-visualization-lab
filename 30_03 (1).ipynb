# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
car_data=pd.read_csv("/content/Toyota.csv")

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   object
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 123.5+ KB

# %%
car_data.dropna(axis=0,inplace=True)
car_data
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# 5              5  12950  32.0  61000   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1425        1425   7950  80.0     ??   Petrol   86       1.0          0  1300
# 1429        1429   8950  78.0  24000   Petrol   86       1.0          1  1300
# 1430        1430   8450  80.0  23000   Petrol   86       0.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
plt.scatter(car_data['Age'],car_data['Price'],c='red')
plt.title('scatter plot of price ad age')
plt.xlabel('age(month)')
plt.ylabel('price(euros)')
plt.show()

# %%
plt.hist(car_data['KM'])
# Out:
# (array([142., 118., 111., 109., 104., 111., 111., 103., 101., 101.]),
#  array([  0.,  99., 198., 297., 396., 495., 594., 693., 792., 891., 990.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(car_data['KM'],color='green',edgecolor='white',bins=30)
plt.title('histogram of KM')
plt.xlabel('kilometer')
plt.ylabel('frequency')
plt.show()

# %%
counts=[198,134,1]
fueltype=['petrol','diesel','cng']
index=np.arange(len(fueltype))

# %%
plt.bar(index,counts,color =['red','blue','cyan'])
plt.title('fuel type')
plt.xlabel('fueltype')
plt.ylabel('frequency')
plt.show()

# %%
x = np.linspace(0,10,10000)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert x to a NumPy array
x = np.array(range(1, 6))

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot(x, x**2, label="x^2")
axes[0].plot(x, np.exp(x), label="exp(x)")
axes[0].set_title("Normal Scale")
axes[0].legend()

axes[1].plot(x, x**2, label="x^2")
axes[1].plot(x, np.exp(x), label="exp(x)")
axes[1].set_title("Logarithmic Scale")
axes[1].set_yscale("log")
axes[1].legend()

plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(10, 4))
axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_title("normal scale")
axes[1].plot(x, x**2, x, np.exp(x))
axes[1].set_yscale("Log")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-eea649c59042> in <cell line: 2>()
#       1 fig, axes = plt.subplots(1,2, figsize=(10, 4))
# ----> 2 axes[0].plot(x, x**2, x, np.exp(x))
#       3 axes[0].set_title("normal scale")
#       4 axes[1].plot(x, x**2, x, np.exp(x))
#       5 axes[1].set_yscale("Log")
#
# TypeError: unsupported operand type(s) for ** or pow(): 'range' and 'int'

# %%
fig,axes=plt.subplots(1,2,figsize=(10,4))
x=car_data["Age"]
axes[0].plot(x,x**2,x,np.exp(x))
axes[0].set_title("Normal scale")

axes[1].plot(x,x**2,x,np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)");

# %%
fig,ax=plt.subplots(figsize=(10,4))

ax.plot(x,x**2,x,x**3,lw=2)

ax.set_xticks([1,2,3,4,5])
ax.set_xtickslabels([r'$\alpha$',r'$\beta$',r'$\gamma$',r'$\delta$',r'$\epsilon$'],fontsize=18)

yticks=[0,50,100,150]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%.1f$" % y for y in yticks],fontsize=18);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-3744c679831b> in <cell line: 6>()
#       4
#       5 ax.set_xticks([1,2,3,4,5])
# ----> 6 ax.set_xtickslabels([r'$\alpha$',r'$\beta$',r'$\gamma$',r'$\delta$',r'$\epsilon$'],fontsize=18)
#       7
#       8 yticks=[0,50,100,150]
#
# AttributeError: 'Axes' object has no attribute 'set_xtickslabels'

# %%
fig,ax=plt.subplots(1,1)

ax.plot(x,x**2,x,np.exp(x))
ax.set_title("scientific notation")

ax.set_yticks([0,50,100,150])

from matplotlib import ticker
formatter=ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax.yaxis.set_major_formatter(formatter)

# %%
import matplotlib

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Print available rcParams keys
# !python -m matplotlib.rcParams keys

# Change the parameter name to 'xtick.major.pad'
matplotlib.rcParams['xtick.major.pad']=5
matplotlib.rcParams['ytick.major.pad']=5

fig,ax=plt.subplots(1,1)

ax.plot(x,x**2,x,np.exp(x))
ax.set_yticks([0,50,100,150])

ax.set_title("label and axis spacing")

ax.xaxis.labelpad=5
ax.yaxis.labelpad=5

ax.set_xlabel("x")
ax.set_ylabel("y");
# Out:
# ...
# /usr/bin/python3: No module named matplotlib.rcParams

# %%
import matplotlib
matplotlib.rcParams['xticks.major.pad']=5
matplotlib.rcParams['yticks.major.pad']=5

fig,ax=plt.subplots(1,1)

ax.plot(x,x**2,x,np.exp(x))
ax.set_yticks([0,50,100,150])

ax.set_title("label and axis spacing")

ax.xaxis.labelpad=5
ax.yaxis.labelpad=5

ax.set_xlabel("x")
ax.set_ylabel("y");
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in __setitem__(self, key, val)
#     715             try:
# --> 716                 cval = self.validate[key](val)
#     717             except ValueError as ve:
#
# KeyError: 'xticks.major.pad'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-731c3a41aafd> in <cell line: 2>()
#       1 import matplotlib
# ----> 2 matplotlib.rcParams['xticks.major.pad']=5
#       3 matplotlib.rcParams['yticks.major.pad']=5
#       4
#       5 fig,ax=plt.subplots(1,1)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in __setitem__(self, key, val)
#     719             self._set(key, cval)
#     720         except KeyError as err:
# ...

# %%
fig,ax=plt.subplots(1,1)

ax.plot(x,x**2,x,np.exp(x))
ax.set_yticks([0,50,100,150])

ax.set_title("Title")
ax.set_xlabel("x")
ax.set_ylabel("y")

fig.subplots_adjust(left=0.15,right=.9,bottom=0.1,top=0.9);

# %%
fig,axes=plt.subplots(1,2,figsize=(10,3))
x=car_data["Price"]
axes[0].plot(x,x**2,x,x**3,lw=2)
axes[0].grid(True)

axes[1].plot(x,x**2,x,x**3,lw=2)
axes[1].grid(color='b',alpha=0.5,linestyle='dashed',linewidth=0.5)

# %%
fig, ax = plt.subplots(figsize=(10, 4))

ax.plot(x, x**2, x, x**3, lw=2)

ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'], fontsize=18)

yticks = [0, 50, 100, 150]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=18)

plt.show()

# %%
import matplotlib

# %%
matplotlib.rcParams['xtick.major.pad']=3
matplotlib.rcParams['ytick.major.pad']=3

# %%
fig,ax=plt.subplots(1,1)

ax.plot(x,x**2,x,np.exp(x))
ax.set_yticks([0,50,100.150])
ax.set_title("title")

ax.set_xlabel("x")
ax.set_ylabel("y")
fig.subplots_adjust(left=0.15,right=0.9,bottom=0.1,top=0.9);
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
fig,axes=plt.subplots(1,2,figsize=(10,3))

axes[0].plot(x,x**2,x,x**3,lw=2)
axes[0].grid(True)

axes[1].plot(x,x**2,x,x**3,lw=2)
axes[1].grid(color='b',alpha=0.5,linestyle='dashed',linewidth=0.5)

# %%
fig,ax=plt.subplots(figsize=(6,2))

ax.spines['bottom'].set_color('blue')
ax.spines['top'].set_color('blue')
ax.spines['left'].set_color('red')
ax.spines['left'].set_linewidth(2)

ax.spines['right'].set_color("none")
ax.yaxis.tick_left()

# %%
#negative axes
fig, ax=plt.subplots()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
xx=np.linspace(-0.75,1.,100)
ax.plot(xx,xx**3);

# %%
n=np.array([0,1,2,3,4,5])

# %%
fig,axes=plt.subplots(1,4,figsize=(12,3))
axes[0].scatter(xx,xx+0.25*np.random.randn(len(xx)))
axes[0].set_title("scatter")
axes[1].step(n,n**2,lw=2)
axes[1].set_title("step")
axes[2].bar(n,n**2,align="center",width=0.5,alpha=0.5)
axes[2].set_title("bar")
axes[3].fill_between(x,x*2,x*3,color="green",alpha=0.5);
axes[3].set_title("fill_between");

# %% [markdown]
# ANNOTATING

# %%
fig,ax=plt.subplots()

ax.plot(xx,xx**2,xx,xx**3)

ax.text(0.15,0.2,r"$y=x^2$",fontsize=20,color="pink")
ax.text(0.65,0.1,r"$y=x^3$",fontsize=20,color="purple");

# %% [markdown]
# SUBPLOTS

# %%
fig, ax=plt.subplots(2,3)
fig.tight_layout()

# %%
fig=plt.figure()
ax1=plt.subplot2grid((3,3),(0,0),colspan=3)
ax2=plt.subplot2grid((3,3),(1,0),colspan=2)
ax3=plt.subplot2grid((3,3),(1,2),rowspan=2)
ax4=plt.subplot2grid((3,3),(2,0))
ax1=plt.subplot2grid((3,3),(2,1))
fig.tight_layout()

# %%
import matplotlib.gridspec as gridspec

# %%
fig=plt.figure()
gs=gridspec.GridSpec(2,3,height_ratios=[2,1],width_ratios=[1,2,1])
for g in gs:
  ax=fig.add_subplot(g)
fig.tight_layout()
